# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

files = []
path = "./results/"
file_extension = "ChenHuangFullrankLowdimRhostructuresMEAN.csv"
file_extension_alternative = "ChenHuangFullrankLowdimFGNstructuresMEAN.csv"
for file in os.listdir(path=path):
    if file.endswith(file_extension) or file.endswith(file_extension_alternative):
        print(file)
        files.append(file)
    else:
        continue

for idx,file in enumerate(files):
    name = file.split("-")
    if file.endswith(file_extension):
        errorType = "AR"
        SigmaX = f"AR({name[5]})"
        SigmaE = f"AR({name[6]})"
    if file.endswith(file_extension_alternative):
        errorType = "FGN"
        SigmaX = f"AR({name[5]})"
        SigmaE = f"FGN({name[6]})"


    df = pd.read_csv(path+file)
    # add column for error type
    df["errorType"] = errorType
    # add column for rhoX
    df["SigmaX"] = SigmaX
    # add column for rhoE
    df["SigmaE"] = SigmaE

    if (idx == 0):
        df_all = df
    else:
        df_all = df_all.append(df)  
    del df

    print(df_all)
# Out:
# 64-32-8-8-16-0.5-0.5-ChenHuangFullrankLowdimRhostructuresMEAN.csv
# 64-32-8-8-16-0-0-ChenHuangFullrankLowdimRhostructuresMEAN.csv
# 64-32-8-8-16-0-0.9-ChenHuangFullrankLowdimFGNstructuresMEAN.csv
# 64-32-8-8-16-0-0.1-ChenHuangFullrankLowdimFGNstructuresMEAN.csv
# 64-32-8-8-16-0.5-0.1-ChenHuangFullrankLowdimFGNstructuresMEAN.csv
# 64-32-8-8-16-0.5-0.9-ChenHuangFullrankLowdimFGNstructuresMEAN.csv
# 64-32-8-8-16-0.5-0-ChenHuangFullrankLowdimRhostructuresMEAN.csv
# 64-32-8-8-16-0-0.5-ChenHuangFullrankLowdimRhostructuresMEAN.csv
#    model    avgMSE   avgSPEC  avgSENS errorType   SigmaX   SigmaE
# 0    MLR  0.048721  0.000000        1        AR  AR(0.5)  AR(0.5)
# 1    RRR  0.048721  0.000000        1        AR  AR(0.5)  AR(0.5)
# 2  SOFAR  0.031051  0.470833        1        AR  AR(0.5)  AR(0.5)
# 3   SRRR  0.061643  0.431250        1        AR  AR(0.5)  AR(0.5)
#    model    avgMSE   avgSPEC  avgSENS errorType   SigmaX   SigmaE
# ...

# %%
df_all[["model", "SigmaX", "SigmaE", "avgMSE", "avgSPEC", "avgSENS"]].to_latex(index=False, float_format="%.4f")
# Out:
# /tmp/ipykernel_489430/4194839258.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df_all[["model", "SigmaX", "SigmaE", "avgMSE", "avgSPEC", "avgSENS"]].to_latex(index=False, float_format="%.4f")
# ...
